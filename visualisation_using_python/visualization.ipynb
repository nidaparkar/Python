# %% [markdown]
# # **Q.1**
# PRACTICE
# Visualize counts of Pokemons according to `Type 2` in a sorted manner using bar-chart
# In this task, you will draw a bar-chart to depict the count distribution of Pokemons according to Type 2 in sorted (descending) manner. The path for the file is stored in a variable named path
# First generate a pandas Series object type_2 that stores the count for every Type 2 in descending order using .value_counts(ascending=False)
# On type_2 use .plot(kind='bar') to generate a bar chart showing the counts for different variants of Type 2
# Finally use .show() to display the plot
# Test Cases:
# The shape of the variable df should be (800,10)
# The shape of the variable type_2 should be (18,)
# The 3rd item in the variable type_2 should be 3

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d8999e02-cd4d-4f57-8476-33429807abda" name="files[]" multiple disabled />
#      <output id="result-d8999e02-cd4d-4f57-8476-33429807abda">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving pokemon.csv to pokemon.csv

# %%
  #import packages
import pandas as pd        
import numpy as np
import matplotlib.pyplot as plt
        # load data
path='pokemon.csv'        
df = pd.read_csv(path)
         # reset index to 'Name'

# %%
df.set_index('Name', inplace=True)
         # drop column '#'
df.drop('#', inplace=True, axis=1)
         # Code starts here
         # Code ends here

# %%
df.shape
# Out:
# (800, 10)

# %%
df
# Out:
#                  Type 1  Type 2  HP  ...  Speed  Generation  Legendary
# Name                                 ...
# Bulbasaur         Grass  Poison  45  ...     45           1      False
# Ivysaur           Grass  Poison  60  ...     60           1      False
# Venusaur          Grass  Poison  80  ...     80           1      False
# Mega Venusaur     Grass  Poison  80  ...     80           1      False
# Charmander         Fire     NaN  39  ...     65           1      False
# ...                 ...     ...  ..  ...    ...         ...        ...
# Diancie            Rock   Fairy  50  ...     50           6       True
# Mega Diancie       Rock   Fairy  50  ...    110           6       True
# Hoopa Confined  Psychic   Ghost  80  ...     70           6       True
# Hoopa Unbound   Psychic    Dark  80  ...     80           6       True
# Volcanion          Fire   Water  80  ...     70           6       True
#
# [800 rows x 10 columns]

# %%
type_2=df['Type 2'].value_counts(ascending=False)
type_2
# Out:
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Rock        14
# Water       14
# Ghost       14
# Ice         14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: Type 2, dtype: int64

# %%
type_2.plot(kind='bar')

# %% [markdown]
# # **Q.2**
# PRACTICE
# How does the mean attack points (`Attack`) for `Type 1` Pokemons fare against `Type 2`?
# In this task, you will use a line plot to compare the mean attack points (Attack) for Type 1 and Type 2 Pokemons
# Create a dataframe type_1 by grouping different categories of Type 1 based on their mean attack (Attack) values using .groupby(['Type 1'])[['Attack']].mean().
# In a similar manner create dataframe type_2 for grouping categories of Type 2 based on their mean attack values
# Reset index permanently for both type_1 and type_2 using .reset_index(inplace=True)
# Merge both type_1 and type_2 using .merge(). Carefully chose left_on and right_on arguments inside the .merge() method and save it as merged
# Drop Type 1 column permanently from merged using .drop(['Type 1'], axis=1, inplace=True)
# Rename 'Type 2' column from merged as Type using .rename()
# First set the figure size using plt.figure(figsize=(14,8))
# Generate a red colored line plot for 'Type 1' Pokemon mean attack points using plt.plot(merged['Type'], merged['Attack_x'], color='red)
# Generate a blue colored line plot for 'Type 2' Pokemon mean attack points in a similar fashion; just replace 'Attackx' with 'Attacky' and 'red' with 'blue'
# Set X-axis label as 'Types' using plt.xlabel()
# Set Y-axis label as 'Mean Attack points' using plt.ylabel()
# Set the plot title as 'Comparison of Mean Attack Points for variants of Type 1 and Type 2' using plt.title()
# Set the Y-axis limit between(45,120)using plt.ylim((45, 120))
# Set legend with axis labels as['Type1', 'Type 2'] as plt.legend(labels=['Type1', 'Type 2'])
# Display the plot using plt.show()

# %%
df
# Out:
#                  Type 1  Type 2  HP  ...  Speed  Generation  Legendary
# Name                                 ...
# Bulbasaur         Grass  Poison  45  ...     45           1      False
# Ivysaur           Grass  Poison  60  ...     60           1      False
# Venusaur          Grass  Poison  80  ...     80           1      False
# Mega Venusaur     Grass  Poison  80  ...     80           1      False
# Charmander         Fire     NaN  39  ...     65           1      False
# ...                 ...     ...  ..  ...    ...         ...        ...
# Diancie            Rock   Fairy  50  ...     50           6       True
# Mega Diancie       Rock   Fairy  50  ...    110           6       True
# Hoopa Confined  Psychic   Ghost  80  ...     70           6       True
# Hoopa Unbound   Psychic    Dark  80  ...     80           6       True
# Volcanion          Fire   Water  80  ...     70           6       True
#
# [800 rows x 10 columns]

# %%
 type_1=df.groupby('Type 1')[['Attack']].mean()
 type_1
# Out:
#               Attack
# Type 1
# Bug        70.971014
# Dark       88.387097
# Dragon    112.125000
# Electric   69.090909
# Fairy      61.529412
# Fighting   96.777778
# Fire       84.769231
# Flying     78.750000
# Ghost      73.781250
# Grass      73.214286
# Ground     95.750000
# Ice        72.750000
# Normal     73.469388
# Poison     74.678571
# Psychic    71.456140
# Rock       92.863636
# Steel      92.703704
# Water      74.151786

# %%
type_2=df.groupby('Type 2')[['Attack']].mean()
type_2
# Out:
#               Attack
# Type 2
# Bug        90.000000
# Dark      109.800000
# Dragon     94.444444
# Electric   72.666667
# Fairy      61.608696
# Fighting  112.846154
# Fire       81.250000
# Flying     80.288660
# Ghost      84.142857
# Grass      74.160000
# Ground     89.857143
# Ice        98.000000
# Normal     52.750000
# Poison     67.588235
# Psychic    74.696970
# Rock       84.000000
# Steel      92.590909
# Water      70.142857

# %%
type_1.reset_index(inplace=True)
type_1
# Out:
#       Type 1      Attack
# 0        Bug   70.971014
# 1       Dark   88.387097
# 2     Dragon  112.125000
# 3   Electric   69.090909
# 4      Fairy   61.529412
# 5   Fighting   96.777778
# 6       Fire   84.769231
# 7     Flying   78.750000
# 8      Ghost   73.781250
# 9      Grass   73.214286
# 10    Ground   95.750000
# 11       Ice   72.750000
# 12    Normal   73.469388
# 13    Poison   74.678571
# 14   Psychic   71.456140
# 15      Rock   92.863636
# 16     Steel   92.703704
# 17     Water   74.151786

# %%
type_2.reset_index(inplace=True)
type_2
# Out:
#       Type 2      Attack
# 0        Bug   90.000000
# 1       Dark  109.800000
# 2     Dragon   94.444444
# 3   Electric   72.666667
# 4      Fairy   61.608696
# 5   Fighting  112.846154
# 6       Fire   81.250000
# 7     Flying   80.288660
# 8      Ghost   84.142857
# 9      Grass   74.160000
# 10    Ground   89.857143
# 11       Ice   98.000000
# 12    Normal   52.750000
# 13    Poison   67.588235
# 14   Psychic   74.696970
# 15      Rock   84.000000
# 16     Steel   92.590909
# 17     Water   70.142857

# %%
merged=pd.merge(left=type_1,right=type_2,left_on=['Type 1'],right_on=['Type 2'],how='inner',suffixes=['_left', '_right'])
print(merged)
# Out:
#       Type 1  Attack_left    Type 2  Attack_right
# 0        Bug    70.971014       Bug     90.000000
# 1       Dark    88.387097      Dark    109.800000
# 2     Dragon   112.125000    Dragon     94.444444
# 3   Electric    69.090909  Electric     72.666667
# 4      Fairy    61.529412     Fairy     61.608696
# 5   Fighting    96.777778  Fighting    112.846154
# 6       Fire    84.769231      Fire     81.250000
# 7     Flying    78.750000    Flying     80.288660
# 8      Ghost    73.781250     Ghost     84.142857
# 9      Grass    73.214286     Grass     74.160000
# 10    Ground    95.750000    Ground     89.857143
# 11       Ice    72.750000       Ice     98.000000
# 12    Normal    73.469388    Normal     52.750000
# 13    Poison    74.678571    Poison     67.588235
# 14   Psychic    71.456140   Psychic     74.696970
# 15      Rock    92.863636      Rock     84.000000
# 16     Steel    92.703704     Steel     92.590909
# 17     Water    74.151786     Water     70.142857

# %%
merged
# Out:
#       Type 1  Attack_left    Type 2  Attack_right
# 0        Bug    70.971014       Bug     90.000000
# 1       Dark    88.387097      Dark    109.800000
# 2     Dragon   112.125000    Dragon     94.444444
# 3   Electric    69.090909  Electric     72.666667
# 4      Fairy    61.529412     Fairy     61.608696
# 5   Fighting    96.777778  Fighting    112.846154
# 6       Fire    84.769231      Fire     81.250000
# 7     Flying    78.750000    Flying     80.288660
# 8      Ghost    73.781250     Ghost     84.142857
# 9      Grass    73.214286     Grass     74.160000
# 10    Ground    95.750000    Ground     89.857143
# 11       Ice    72.750000       Ice     98.000000
# 12    Normal    73.469388    Normal     52.750000
# 13    Poison    74.678571    Poison     67.588235
# 14   Psychic    71.456140   Psychic     74.696970
# 15      Rock    92.863636      Rock     84.000000
# 16     Steel    92.703704     Steel     92.590909
# 17     Water    74.151786     Water     70.142857

# %%
merged.drop(['Type 1'], inplace=True, axis=1)# if you run dro twice it gives error
merged
# Out:
#     Attack_left    Type 2  Attack_right
# 0     70.971014       Bug     90.000000
# 1     88.387097      Dark    109.800000
# 2    112.125000    Dragon     94.444444
# 3     69.090909  Electric     72.666667
# 4     61.529412     Fairy     61.608696
# 5     96.777778  Fighting    112.846154
# 6     84.769231      Fire     81.250000
# 7     78.750000    Flying     80.288660
# 8     73.781250     Ghost     84.142857
# 9     73.214286     Grass     74.160000
# 10    95.750000    Ground     89.857143
# 11    72.750000       Ice     98.000000
# 12    73.469388    Normal     52.750000
# 13    74.678571    Poison     67.588235
# 14    71.456140   Psychic     74.696970
# 15    92.863636      Rock     84.000000
# 16    92.703704     Steel     92.590909
# 17    74.151786     Water     70.142857

# %%
merged
# Out:
#     Attack_left    Type 2  Attack_right
# 0     70.971014       Bug     90.000000
# 1     88.387097      Dark    109.800000
# 2    112.125000    Dragon     94.444444
# 3     69.090909  Electric     72.666667
# 4     61.529412     Fairy     61.608696
# 5     96.777778  Fighting    112.846154
# 6     84.769231      Fire     81.250000
# 7     78.750000    Flying     80.288660
# 8     73.781250     Ghost     84.142857
# 9     73.214286     Grass     74.160000
# 10    95.750000    Ground     89.857143
# 11    72.750000       Ice     98.000000
# 12    73.469388    Normal     52.750000
# 13    74.678571    Poison     67.588235
# 14    71.456140   Psychic     74.696970
# 15    92.863636      Rock     84.000000
# 16    92.703704     Steel     92.590909
# 17    74.151786     Water     70.142857

# %%
merged.rename({"Type 2":"Type"}, inplace=True, axis='columns')# got correct answer after putting axis=columns

# %%
merged
# Out:
#     Attack_left      Type  Attack_right
# 0     70.971014       Bug     90.000000
# 1     88.387097      Dark    109.800000
# 2    112.125000    Dragon     94.444444
# 3     69.090909  Electric     72.666667
# 4     61.529412     Fairy     61.608696
# 5     96.777778  Fighting    112.846154
# 6     84.769231      Fire     81.250000
# 7     78.750000    Flying     80.288660
# 8     73.781250     Ghost     84.142857
# 9     73.214286     Grass     74.160000
# 10    95.750000    Ground     89.857143
# 11    72.750000       Ice     98.000000
# 12    73.469388    Normal     52.750000
# 13    74.678571    Poison     67.588235
# 14    71.456140   Psychic     74.696970
# 15    92.863636      Rock     84.000000
# 16    92.703704     Steel     92.590909
# 17    74.151786     Water     70.142857

# %%
plt.figure(figsize=(14,8))

# %%
plt.plot(merged['Type'], merged['Attack_left'], color='red')
plt.plot(merged['Type'], merged['Attack_right'], color='blue')
plt.xlabel('Types')
plt.ylabel('Mean Attack points')
plt.title('Comparison of Mean Attack Points for variants of Type 1 and Type 2')
plt.ylim((45, 120))
plt.legend(labels=['Type1', 'Type 2'])

# %%
plt.show()

# %%
df
# Out:
#                  Type 1  Type 2  HP  ...  Speed  Generation  Legendary
# Name                                 ...
# Bulbasaur         Grass  Poison  45  ...     45           1      False
# Ivysaur           Grass  Poison  60  ...     60           1      False
# Venusaur          Grass  Poison  80  ...     80           1      False
# Mega Venusaur     Grass  Poison  80  ...     80           1      False
# Charmander         Fire     NaN  39  ...     65           1      False
# ...                 ...     ...  ..  ...    ...         ...        ...
# Diancie            Rock   Fairy  50  ...     50           6       True
# Mega Diancie       Rock   Fairy  50  ...    110           6       True
# Hoopa Confined  Psychic   Ghost  80  ...     70           6       True
# Hoopa Unbound   Psychic    Dark  80  ...     80           6       True
# Volcanion          Fire   Water  80  ...     70           6       True
#
# [800 rows x 10 columns]

# %% [markdown]
# # **Q.3**
# Practice
# Which generation has the highest chances of being legendary?
# In this task you will answer the question:
# Which generation (Generation) has the highest chances of being legendary (Legendary)
# First group Pokemons by Generation and Legendary and then calculate the counts for every variant of generation based on legendary status (True or False). Save this to a variable res
# Plot a stacked bar chart using .plot(kind='bar', stacked=True, figsize=(15,10)) method

# %%
res=df.groupby(['Generation', 'Legendary']).size().unstack().plot(kind='bar', stacked=True, figsize=(15,10))

plt.show()

# %% [markdown]
# # **Q.4**
# PRACTICE
# Visualize the distribution of `Attack` points for `Dragon` type (`Type 1`) Pokemons
# In this task, you will plot the distribution of Attack points for Pokemons which have their first type (Type 1) as Dragon. You will also compare the mean values for Attack for all the Pokemons against the mean value of Attack for dragon type (by drawing a vertical line).
# Calculate the mean attack points for all the Pokemons and store it in a variable mean_attack
# Create a dataframe named dragon consisting of only Dragon type pokemon using conditional filtering (based on Type 1)
# Calculate the mean attack points for dragon and store it in a variable mean_dragon
# Use matplotlib's .hist() on dragon and pass arguments column='Attack', bins=8
# To compare mean attack points you need to draw two lines; one with mean_attack and mean_dragon
# Use .axvline() and pass arguments x=mean_attack, color='green' to plot a vertical line representing mean attack points for all the Pokemons
# Use .axvline() and pass arguments x=mean_dragon, color='black' to plot a vertical line representing mean attack points for Dragon Pokemons

# %%
df
# Out:
#                  Type 1  Type 2  HP  ...  Speed  Generation  Legendary
# Name                                 ...
# Bulbasaur         Grass  Poison  45  ...     45           1      False
# Ivysaur           Grass  Poison  60  ...     60           1      False
# Venusaur          Grass  Poison  80  ...     80           1      False
# Mega Venusaur     Grass  Poison  80  ...     80           1      False
# Charmander         Fire     NaN  39  ...     65           1      False
# ...                 ...     ...  ..  ...    ...         ...        ...
# Diancie            Rock   Fairy  50  ...     50           6       True
# Mega Diancie       Rock   Fairy  50  ...    110           6       True
# Hoopa Confined  Psychic   Ghost  80  ...     70           6       True
# Hoopa Unbound   Psychic    Dark  80  ...     80           6       True
# Volcanion          Fire   Water  80  ...     70           6       True
#
# [800 rows x 10 columns]

# %%
mean_attack=df['Attack'].mean(axis=0)
mean_attack
# Out:
# 79.00125

# %%
dragon=df[df['Type 1']=='Dragon']
dragon
# Out:
#                      Type 1    Type 2   HP  ...  Speed  Generation  Legendary
# Name                                        ...
# Dratini              Dragon       NaN   41  ...     50           1      False
# Dragonair            Dragon       NaN   61  ...     70           1      False
# Dragonite            Dragon    Flying   91  ...     80           1      False
# Altaria              Dragon    Flying   75  ...     80           3      False
# Mega Altaria         Dragon     Fairy   75  ...     80           3      False
# Bagon                Dragon       NaN   45  ...     50           3      False
# Shelgon              Dragon       NaN   65  ...     50           3      False
# Salamence            Dragon    Flying   95  ...    100           3      False
# Mega Salamence       Dragon    Flying   95  ...    120           3      False
# Latias               Dragon   Psychic   80  ...    110           3       True
# Mega Latias          Dragon   Psychic   80  ...    110           3       True
# Latios               Dragon   Psychic   80  ...    110           3       True
# Mega Latios          Dragon   Psychic   80  ...    110           3       True
# Rayquaza             Dragon    Flying  105  ...     95           3       True
# Mega Rayquaza        Dragon    Flying  105  ...    115           3       True
# Gible                Dragon    Ground   58  ...     42           4      False
# Gabite               Dragon    Ground   68  ...     82           4      False
# Garchomp             Dragon    Ground  108  ...    102           4      False
# Mega Garchomp        Dragon    Ground  108  ...     92           4      False
# Axew                 Dragon       NaN   46  ...     57           5      False
# Fraxure              Dragon       NaN   66  ...     67           5      False
# Haxorus              Dragon       NaN   76  ...     97           5      False
# Druddigon            Dragon       NaN   77  ...     48           5      False
# Reshiram             Dragon      Fire  100  ...     90           5       True
# Zekrom               Dragon  Electric  100  ...     90           5       True
# Kyurem               Dragon       Ice  125  ...     95           5       True
# Kyurem Black Kyurem  Dragon       Ice  125  ...     95           5       True
# Kyurem White Kyurem  Dragon       Ice  125  ...     95           5       True
# Goomy                Dragon       NaN   45  ...     40           6      False
# Sliggoo              Dragon       NaN   68  ...     60           6      False
# Goodra               Dragon       NaN   90  ...     80           6      False
# Zygarde Half Forme   Dragon    Ground  108  ...     95           6       True
#
# [32 rows x 10 columns]

# %%
mean_dragon=dragon['Attack'].mean(axis=0)
mean_dragon
# Out:
# 112.125

# %%
dragon.hist(column='Attack',bins=8)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3457bcfda0>]],
#       dtype=object)

# %%
plt.axvline( x=mean_attack, color='green')

# %%
plt.axvline( x=mean_dragon, color='black')

# %% [markdown]
# # **Q.5**
# PRACTICE
# Do electric pokemons have a correlation between their health and attack?
# In this task, you will draw a scatter plot to understand if there is a trend between their health (HP) and attack (Attack) for Pokemons having 'Electric' as their first type (Type 1)
# Create a new dataframe electric using conditional filtering for selecting pokemon having Type 1 as 'Electric'
# Use pandas .plot.scatter(x,y) method to draw a scatter plot with X-axes values as HP and Y-axes values as Attack points

# %%
electric=df[df['Type 1']=='Electric']
electric
# Out:
#                              Type 1  Type 2  HP  ...  Speed  Generation  Legendary
# Name                                             ...
# Pikachu                    Electric     NaN  35  ...     90           1      False
# Raichu                     Electric     NaN  60  ...    110           1      False
# Magnemite                  Electric   Steel  25  ...     45           1      False
# Magneton                   Electric   Steel  50  ...     70           1      False
# Voltorb                    Electric     NaN  40  ...    100           1      False
# Electrode                  Electric     NaN  60  ...    140           1      False
# Electabuzz                 Electric     NaN  65  ...    105           1      False
# Jolteon                    Electric     NaN  65  ...    130           1      False
# Zapdos                     Electric  Flying  90  ...    100           1       True
# Pichu                      Electric     NaN  20  ...     60           2      False
# Mareep                     Electric     NaN  55  ...     35           2      False
# Flaaffy                    Electric     NaN  70  ...     45           2      False
# Ampharos                   Electric     NaN  90  ...     55           2      False
# Mega Ampharos              Electric  Dragon  90  ...     45           2      False
# Elekid                     Electric     NaN  45  ...     95           2      False
# Raikou                     Electric     NaN  90  ...    115           2       True
# Electrike                  Electric     NaN  40  ...     65           3      False
# Manectric                  Electric     NaN  70  ...    105           3      False
# Mega Manectric             Electric     NaN  70  ...    135           3      False
# Plusle                     Electric     NaN  60  ...     95           3      False
# Minun                      Electric     NaN  60  ...     95           3      False
# Shinx                      Electric     NaN  45  ...     45           4      False
# Luxio                      Electric     NaN  60  ...     60           4      False
# Luxray                     Electric     NaN  80  ...     70           4      False
# Pachirisu                  Electric     NaN  60  ...     95           4      False
# Magnezone                  Electric   Steel  70  ...     60           4      False
# Electivire                 Electric     NaN  75  ...     95           4      False
# Rotom                      Electric   Ghost  50  ...     91           4      False
# Heat Rotom                 Electric    Fire  50  ...     86           4      False
# Wash Rotom                 Electric   Water  50  ...     86           4      False
# Frost Rotom                Electric     Ice  50  ...     86           4      False
# Fan Rotom                  Electric  Flying  50  ...     86           4      False
# Mow Rotom                  Electric   Grass  50  ...     86           4      False
# Blitzle                    Electric     NaN  45  ...     76           5      False
# Zebstrika                  Electric     NaN  75  ...    116           5      False
# Emolga                     Electric  Flying  55  ...    103           5      False
# Tynamo                     Electric     NaN  35  ...     60           5      False
# Eelektrik                  Electric     NaN  65  ...     40           5      False
# Eelektross                 Electric     NaN  85  ...     50           5      False
# Thundurus Incarnate Forme  Electric  Flying  79  ...    111           5       True
# Thundurus Therian Forme    Electric  Flying  79  ...    101           5       True
# Helioptile                 Electric  Normal  44  ...     70           6      False
# Heliolisk                  Electric  Normal  62  ...    109           6      False
# Dedenne                    Electric   Fairy  67  ...    101           6      False
#
# [44 rows x 10 columns]

# %%
electric.plot.scatter(x='HP', y='Attack')

# %% [markdown]
# # **Q.6**
# PRACTICE
# Legendary higher chances - a different view
# In this task, you will visualize with the help of a stacked bar-chart which generation (1,2,3,4,5,6) has the highest chances of being Legendary with the help of percentages as well as counts
# You will be comparing two stacked bar-charts; one with percentages and the other with counts representing Legendary counts/percentages for every variant of Type 1
# Initialize two axes ax_1 and ax_2 using .subplots(1,2, figsize=(20,10)
# For the first plot, first group Pokemons by Generation and Legendary and then calculate the counts for every variant of generation based on legendary status (True or False). Save this to a variable res
# Plot a stacked bar chart in the first axes using .plot(kind='bar', stacked=True, ax=ax_1)
# For the second plot, make a new dataframe new_res by filling missing values of res with 0 using .fillna(0)
# Convert the values in this frame to percentages in a manner similar to the code snippet given in the topic
# Plot the second stacked bar-chart using ax=ax_2 inside the .plot() on new_res

# %%
fig, (ax_1, ax_2) = plt.subplots(1,2, figsize=(20,10))
res = df.groupby(['Generation', 'Legendary']).size().unstack()
res.plot(kind='bar', stacked=True, ax=ax_1)
new_res = res.fillna(0)
new_res['Total'] = new_res[True] + new_res[False]
new_res[True] = (new_res[True] / new_res['Total']) * 100
new_res[False] = (new_res[False] / new_res['Total']) * 100
new_res.drop('Total', inplace=True, axis=1)
new_res.plot(kind='bar', stacked=True, ax=ax_2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-c1996931c356> in <module>()
#       1 fig, (ax_1, ax_2) = plt.subplots(1,2, figsize=(20,10))
# ----> 2 res = df.groupby(['Generation', 'Legendary']).size().unstack()
#       3 res.plot(kind='bar', stacked=True, ax=ax_1)
#       4 new_res = res.fillna(0)
#       5 new_res['Total'] = new_res[True] + new_res[False]
#
# NameError: name 'df' is not defined

# %% [markdown]
# # **PROJECT**

# %% [markdown]
# Visualization for company stakeholders
#
#
# Problem Statement
# You have been hired by the stakeholders of Dream Housing Finance company to help them get visual insights on the company's operations. Using the data visualization techniques you learned, you have to help visualise the data and see if you can help the stakeholders arrive at some inference based on the visual plots.
# About the Dataset
# The snapshot of the data, you will be working on:
#
#
# The dataset has details of 614 customers with the following 13 features
# Feature
# Description
# Loan_ID
# Unique Loan ID
# Gender
# Male/Female
# Married
# Applicant Married (Y/N)
# Dependents
# Number of dependents
# Education
# Graduate/Under Graduate
# Self_Employed
# Self employed (Y/N)
# ApplicantIncome
# Income of the applicant
# CoapplicantIncome
# Income of the co applicant
# LoanAmount
# Loan amount in thousands
# LoanAmountTerm
# Term of loan in months
# Credit_History
# credit hostory meets guidelines}
# Property_Area
# Urban/Semi-Urban/Rural
# Loan_Status
# Loan approved (Y/N)
# Why solve this project?
# After completing this project, you will have a better understanding of data visualization techniques. In this project, you will be applying the following concepts:
# Bar plotting
# Scatter plotting
# Kernel Density plotting
# Subplot operations
# Axes modifications
#
#
# ======================================================================
#
# Loan Status
# Loan Status
# Let's start with the simple task of visualizing the company's record with respect to loan approvals.
# The path to the dataset has been stored in a variable path
# Load the dataframe using pd.read_csv() and store the dataframe in a variable called data.
# Save the value counts of Loan_Status in a variable called loan_status using value_counts()
# Plot a bar graph of loan_status
# Things to ponder upon:
#  - Company has more 'loan approvals' or 'loan disapprovals'?
#   - Can one of the company's health factors be its loan status distribution?
# #Importing header files
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# #Code starts here
#
# =====================================================================
#
#
#
# Everyone needs money
# Everyone needs money
# The company provides financial assistance across the different regions of the country. One interesting statistic that stakeholders want to see is the loan approval distribution across the regions.
# Instructions :
# Group the 'data' dataframe by Property_Area and Loan_Status and store it in a variable called 'property_and_loan'
# Use the .size() method on 'property_and_loan' and then use .unstack() and save it back to 'property_and_loan'
# Plot an unstacked bar plot of property_and_loan (It is similar to creating a stacked bar plot except change the parameter 'stacked' to False)
# Name the x-axis as Property Area
# Name the y-axis as Loan Status
# Rotate the labels of x-axis by 45o
# Things to ponder upon
# - Which is the region with the highest no. of loan approvals? lowest no. of loan approvals?
#
# - Which is the region with the maximum difference between loan approvals and loan rejections?
#
#
# #Code starts here
#
#
#
# =================================================================
#
# Expensive Education
# Expensive Education
# Higher education has always been an expensive endeavour for people but it results in better career opportunities and stability in life. But does higher education result in a better guarantee in issuing loans?
# Instructions :
# Group the 'data' dataframe by Education and Loan_Status and store it in a variable called 'education_and_loan'
# Use the .size() method on 'education_and_loan' and then use .unstack() and save it back to 'education_and_loan'
# Plot an stacked bar plot of education_and_loan
# Name the x-axis as Education Status
# Name the y-axis as Loan Status
# Rotate the labels of x-axis by 45o
# Things to ponder upon
# - Overall which group has asked for higher loan services irrespective of the approval? Graduate or Non-Graduate?
# - Which group has had better approval to non-approval ratio? Graduate or Non-Graduate?
#
#   Do the above conclusions make sense? Why?
#
# #Code starts here
#
# ======================================================================
#
#
# Smarter and Richer?
# Smarter and Richer?
# After seeing the loan status distribution, let's check whether being graduate or not also leads to different loan amount distribution by plotting an overlapping density plot of two values
# Instructions :
# Create a dataframe called 'graduate' which is a subset of 'data' dataframe with the condition "data['Education'] == 'Graduate'"
# Create a dataframe called 'not_graduate' which is a subset of 'data' dataframe with the condition "data['Education'] == 'Not Graduate'"
# Plot a density plot LoanAmount of 'graduate' dataframe using "Series.plot()" and pass the parameter kind='density' and label='Graduate'
# Do the same for LoanAmount of 'not_graduate' dataframe but with label='Not Graduate'
# Things to ponder upon
# - Do Graduate people get approved a higher amount than their Non Graduate counterparts?
#
# - What's the average amount of loan approved for Graduate? for Non-Graduate? Is there a huge difference between the two?
#
#
# #Code starts here
#
#
# =======================================================================
#
# Income vs Loan
# For any financial institution to be successful in its loan lending system, there has to be a correlation between the borrower's income and loan amount he is lent. Let's see how our company fares in that respect:
# Instructions :
# Create three subplots with (nrows = 3 , ncols = 1) and store it in variable's fig ,(ax_1,ax_2,ax_3)
# Since both are continuous variables, plot scatter plot between 'ApplicantIncome' and LoanAmount using ax_1. Set axis title as Applicant Income
# Plot scatter plot between 'CoapplicantIncome' and LoanAmount using ax_2. Set axis title as Coapplicant Income
# Create a new column in the dataframe called 'TotalIncome' which is a sum of the values of columns ApplicantIncome and CoapplicantIncome
# Plot scatter plot between 'TotalIncome' and LoanAmount using ax_3. Set axis title as Total Income
# Things to ponder upon
# - Is there a correlation between 'ApplicantIncome' and 'LoanAmount'?(One way to know that is looking at the line formed when you connect the scatter plot dots?)
#
# - Is the 'TotalIncome' better related to the 'LoanAmount' than 'ApplicantIncome'?

# %% [markdown]
# **step1**
# Loan Status
# Let's start with the simple task of visualizing the company's record with respect to loan approvals.
# The path to the dataset has been stored in a variable path
# Load the dataframe using pd.read_csv() and store the dataframe in a variable called data.
# Save the value counts of Loan_Status in a variable called loan_status using value_counts()
# Plot a bar graph of loan_status
# Things to ponder upon:
#  - Company has more 'loan approvals' or 'loan disapprovals'?
#   - Can one of the company's health factors be its loan status distribution?

# %%
#Importing header files
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-79f52fc1-4d05-44cb-a4fa-55f624ed84d6" name="files[]" multiple disabled />
#      <output id="result-79f52fc1-4d05-44cb-a4fa-55f624ed84d6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
path='company.csv'        
data = pd.read_csv(path)

# %%
data
# Out:
#       Loan_ID  Gender Married  ... Credit_History Property_Area Loan_Status
# 0    LP001002    Male      No  ...            1.0         Urban           Y
# 1    LP001003    Male     Yes  ...            1.0         Rural           N
# 2    LP001005    Male     Yes  ...            1.0         Urban           Y
# 3    LP001006    Male     Yes  ...            1.0         Urban           Y
# 4    LP001008    Male      No  ...            1.0         Urban           Y
# ..        ...     ...     ...  ...            ...           ...         ...
# 595  LP002978  Female      No  ...            1.0         Rural           Y
# 596  LP002979    Male     Yes  ...            1.0         Rural           Y
# 597  LP002983    Male     Yes  ...            1.0         Urban           Y
# 598  LP002984    Male     Yes  ...            1.0         Urban           Y
# 599  LP002990  Female      No  ...            0.0     Semiurban           N
#
# [600 rows x 13 columns]

# %%
loan_status=data['Loan_Status'].value_counts()
loan_status
# Out:
# Y    415
# N    185
# Name: Loan_Status, dtype: int64

# %%
plt.figure(figsize=[10,5])
 
# label the axes
plt.xlabel("status of loan")
plt.ylabel("No of ppl")
 
# title the plot
plt.title("Loan status")
 
# build and show the plot
plt.bar(loan_status.index,loan_status)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# # **Step2**
#
# Everyone needs money
# Everyone needs money
# The company provides financial assistance across the different regions of the country. One interesting statistic that stakeholders want to see is the loan approval distribution across the regions.
# Instructions :
# Group the 'data' dataframe by Property_Area and Loan_Status and store it in a variable called 'property_and_loan'
# Use the .size() method on 'property_and_loan' and then use .unstack() and save it back to 'property_and_loan'
# Plot an unstacked bar plot of property_and_loan (It is similar to creating a stacked bar plot except change the parameter 'stacked' to False)
# Name the x-axis as Property Area
# Name the y-axis as Loan Status
# Rotate the labels of x-axis by 45o
# Things to ponder upon
# - Which is the region with the highest no. of loan approvals? lowest no. of loan approvals?
#
# - Which is the region with the maximum difference between loan approvals and loan rejections?

# %%
plt.figure(figsize=(14,8))
property_and_loan = data.groupby(['Property_Area', 'Loan_Status']).size().unstack()
property_and_loan.plot(kind='bar', stacked=False)
plt.xlabel('Property_Area')
plt.ylabel('Loan_Status')
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2]), <a list of 3 Text major ticklabel objects>)

# %% [markdown]
# # **Step3**
#
# Expensive Education
# Expensive Education
# Higher education has always been an expensive endeavour for people but it results in better career opportunities and stability in life. But does higher education result in a better guarantee in issuing loans?
# Instructions :
# Group the 'data' dataframe by Education and Loan_Status and store it in a variable called 'education_and_loan'
# Use the .size() method on 'education_and_loan' and then use .unstack() and save it back to 'education_and_loan'
# Plot an stacked bar plot of education_and_loan
# Name the x-axis as Education Status
# Name the y-axis as Loan Status
# Rotate the labels of x-axis by 45o
# Things to ponder upon
# - Overall which group has asked for higher loan services irrespective of the approval? Graduate or Non-Graduate?
# - Which group has had better approval to non-approval ratio? Graduate or Non-Graduate?
#
#   Do the above conclusions make sense? Why?

# %%
plt.figure(figsize=(14,8))
education_and_loan = data.groupby(['Education', 'Loan_Status']).size().unstack()
education_and_loan.plot(kind='bar', stacked=True)
plt.xlabel('Education Status')
plt.ylabel('Loan_Status')
plt.xticks(rotation=45)
# Out:
# (array([0, 1]), <a list of 2 Text major ticklabel objects>)

# %% [markdown]
# # **Step4**
#
# Smarter and Richer?
# Smarter and Richer?
# After seeing the loan status distribution, let's check whether being graduate or not also leads to different loan amount distribution by plotting an overlapping density plot of two values
# Instructions :
# Create a dataframe called 'graduate' which is a subset of 'data' dataframe with the condition "data['Education'] == 'Graduate'"
# Create a dataframe called 'not_graduate' which is a subset of 'data' dataframe with the condition "data['Education'] == 'Not Graduate'"
# Plot a density plot LoanAmount of 'graduate' dataframe using "Series.plot()" and pass the parameter kind='density' and label='Graduate'
# Do the same for LoanAmount of 'not_graduate' dataframe but with label='Not Graduate'
# Things to ponder upon
# - Do Graduate people get approved a higher amount than their Non Graduate counterparts?
#
# - What's the average amount of loan approved for Graduate? for Non-Graduate? Is there a huge difference between the two?

# %%
graduate=data[data['Education'] == 'Graduate']
not_graduate=data[data['Education'] == 'Not Graduate']
plt.Series.plot(kind='density',label='Graduate')#check which is working fine this or line below
not_graduate.Series.plot(kind='density',label='Not Graduate')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-2f91b2a18989> in <module>()
#       1 graduate=data[data['Education'] == 'Graduate']
#       2 not_graduate=data[data['Education'] == 'Not Graduate']
# ----> 3 plt.Series.plot(kind='density',label='Graduate')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'Series'

# %% [markdown]
# # **Step5**
#
# Income vs Loan
# For any financial institution to be successful in its loan lending system, there has to be a correlation between the borrower's income and loan amount he is lent. Let's see how our company fares in that respect:
# Instructions :
# Create three subplots with (nrows = 3 , ncols = 1) and store it in variable's fig ,(ax_1,ax_2,ax_3)
# Since both are continuous variables, plot scatter plot between 'ApplicantIncome' and LoanAmount using ax_1. Set axis title as Applicant Income
# Plot scatter plot between 'CoapplicantIncome' and LoanAmount using ax_2. Set axis title as Coapplicant Income
# Create a new column in the dataframe called 'TotalIncome' which is a sum of the values of columns ApplicantIncome and CoapplicantIncome
# Plot scatter plot between 'TotalIncome' and LoanAmount using ax_3. Set axis title as Total Income
# Things to ponder upon
# - Is there a correlation between 'ApplicantIncome' and 'LoanAmount'?(One way to know that is looking at the line formed when you connect the scatter plot dots?)
#
# - Is the 'TotalIncome' better related to the 'LoanAmount' than 'ApplicantIncome'?

# %%
data
# Out:
#       Loan_ID  Gender Married  ... Credit_History Property_Area Loan_Status
# 0    LP001002    Male      No  ...            1.0         Urban           Y
# 1    LP001003    Male     Yes  ...            1.0         Rural           N
# 2    LP001005    Male     Yes  ...            1.0         Urban           Y
# 3    LP001006    Male     Yes  ...            1.0         Urban           Y
# 4    LP001008    Male      No  ...            1.0         Urban           Y
# ..        ...     ...     ...  ...            ...           ...         ...
# 595  LP002978  Female      No  ...            1.0         Rural           Y
# 596  LP002979    Male     Yes  ...            1.0         Rural           Y
# 597  LP002983    Male     Yes  ...            1.0         Urban           Y
# 598  LP002984    Male     Yes  ...            1.0         Urban           Y
# 599  LP002990  Female      No  ...            0.0     Semiurban           N
#
# [600 rows x 13 columns]

# %%
fig, (ax_1, ax_2, ax_3) = plt.subplots(1,3, figsize=(20,8))
data.plot.scatter(x='ApplicantIncome', y='LoanAmount',ax=ax_1,title='Applicant Income')
data.plot.scatter(x='CoapplicantIncome', y='LoanAmount',ax=ax_2,title='Co Applicant Income')
data['TotalIncome']=data['ApplicantIncome']+data['CoapplicantIncome']
data.plot.scatter(x='TotalIncome', y='LoanAmount',ax=ax_3,title='Total Income')
